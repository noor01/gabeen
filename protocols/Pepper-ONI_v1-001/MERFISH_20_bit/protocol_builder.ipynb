# %%
import json
import os
import pandas as pd

# %%
experiment = {}

# %%
step_n = 0

# %%
fluids = pd.read_csv('fluids.csv')

# %%
fluids[fluids['BufferName']=='round_1']['NodeID'].iloc[0]
# Out:
# '6'

# %%
def get_fluid_node(buffer):
    return fluids[fluids['BufferName']==buffer]['NodeID'].iloc[0]

# %%
for round_n in range(1,11):
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node(f'round_{round_n}')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 15*60 # 15 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('wash buffer')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('universal_fluors')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 15*60 # 15 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('wash buffer')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('imaging buffer')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 5*60 # 5 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'image'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['filename'] = f'round_{round_n}'
    experiment[step_n]['slack_notify'] = True
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('tcep')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 5*60 # 5 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('2x-SSC')
    experiment[step_n]['step_metadata']['volume'] = 5
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1

# %%
experiment
# Out:
# {0: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  1: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  2: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  3: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  4: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  5: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  6: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  7: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  8: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_1'},
#   'slack_notify': True},
#  9: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  10: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  11: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  12: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '15', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  13: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  14: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  15: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  16: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  17: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  18: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  19: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  20: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_2'},
#   'slack_notify': True},
#  21: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  22: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  23: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  24: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '16', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  25: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  26: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  27: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  28: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  29: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  30: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  31: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  32: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_3'},
#   'slack_notify': True},
#  33: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  34: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  35: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  36: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '17', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  37: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  38: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  39: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  40: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  41: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  42: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  43: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  44: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_4'},
#   'slack_notify': True},
#  45: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  46: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  47: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  48: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '18', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  49: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  50: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  51: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  52: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  53: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  54: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  55: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  56: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_5'},
#   'slack_notify': True},
#  57: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  58: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  59: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  60: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '19', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  61: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  62: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  63: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  64: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  65: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  66: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  67: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  68: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_6'},
#   'slack_notify': True},
#  69: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  70: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  71: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  72: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '20', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  73: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  74: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  75: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  76: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  77: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  78: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  79: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  80: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_7'},
#   'slack_notify': True},
#  81: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  82: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  83: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  84: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '21', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  85: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  86: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  87: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  88: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  89: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  90: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  91: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  92: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_8'},
#   'slack_notify': True},
#  93: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  94: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  95: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  96: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '22', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  97: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  98: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  99: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  100: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  101: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  102: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  103: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  104: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_9'},
#   'slack_notify': True},
#  105: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  106: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  107: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  108: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '23', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  109: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  110: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  111: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  112: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  113: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '1', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  114: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  115: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  116: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_10'},
#   'slack_notify': True},
#  117: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  118: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  119: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 5, 'speed': 1},
#   'slack_notify': False}}

# %%
with open('experiment.json', 'w+') as f:
    json.dump(experiment, f, indent=4)
