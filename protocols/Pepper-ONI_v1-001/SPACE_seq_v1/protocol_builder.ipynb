# %%
# %load_ext autoreload
# %autoreload 2
import json
import sys
import os
import pandas as pd
from math import floor
import numpy as np
import pickle
sys.path.append(os.path.abspath('../../../utils'))
from protocol_system_compiler import *

# %%
fluids = pd.read_csv('fluids.csv')

# %%
fluids
# Out:
#   NodeID    FluidType        BufferName  LoadVolume
# 0    ot2       source               ot2           3
# 1      2       source       wash buffer          40
# 2      3       source    imaging buffer          21
# 3      4       source              tcep          20
# 4      5       source            2x-SSC          50
# 5      6       source  universal_fluors          15
# 6  waste  destination        waste_tank           0

# %%
labware = {'tips_200':{
    'api_name': 'opentrons_96_filtertiprack_200ul',
    'location': '1'
},
              'tips_1000':{
    'api_name': 'opentrons_96_filtertiprack_1000ul',
    'location': '2'
              },
              'reservoir1':{
    'api_name': 'nest_12_reservoir_15ml',
    'location': '3'
                },
              'wellplate1':{
    'api_name': 'nest_96_wellplate_2ml_deep',
    'location': '4'
                },
              'tuberack_50ml_1':{
    'api_name': 'opentrons_6_tuberack_falcon_50ml_conical',
    'location': '5'
                },
              'tuberack_15ml_1':{
    'api_name': 'opentrons_10_tuberack_falcon_4x50ml_6x15ml_conical',
    'location': '6'
                },
              'syringe_adapter':{
    'api_name': 'yeolab_1_bd_syringe_adap_3000ul',
    'location': '10'
                },
              }
hardware = {'p300':{
    'api_name': 'p300_single_gen2',
    'mount': 'left',
    'tip_racks': ['tips_200']},
            'p1000':{
    'api_name': 'p1000_single_gen2',
    'mount': 'right',
    'tip_racks': ['tips_1000']}}

metadata = {'apiLevel': '2.14'}

ot2_config = {'labware':labware,
              'hardware':hardware,
              'metadata':metadata}

# %%
reagents = {}
"""
reagents = {'wash buffer1':{'labware':'tuberack_50ml_1',
                           'location':'A1',
                           'volume':1000,
                           'hardware;':'p1000',
                           'repeat':2},
            'wash buffer2':{'labware':'tuberack_50ml_1',
                            'location':'A2',
                            'volume':1000,
                           'hardware;':'p1000',
                           'repeat':2},
            'wash buffer3':{'labware':'tuberack_50ml_1',
                            'location':'A3',
                            'volume':1000,
                           'hardware;':'p1000',
                           'repeat':2},
            'wash buffer4':{'labware':'tuberack_50ml_1',
                            'location':'B1',
                            'volume':1000,
                           'hardware;':'p1000',
                           'repeat':2},
            'imaging buffer':{'labware':'tuberack_50ml_1',
                                'location':'B2',
                                'volume':750,
                           'hardware;':'p1000',
                           'repeat':2},
            'tcep':{'labware':'tuberack_50ml_1',
                                'location':'B3',
                                'volume':1000,
                           'hardware;':'p1000',
                           'repeat':2},
            '2x-SSC':{'labware':'tuberack_50ml_1',
                                'location':'A5',
                                'volume':833,
                           'hardware;':'p1000',
                           'repeat':3},
            'universal_fluors':{'labware':'tuberack_15ml_1',
                                'location':'A1',
                                'volume':750,
                           'hardware;':'p1000',
                           'repeat':2}}
"""
# Out:
# "\nreagents = {'wash buffer1':{'labware':'tuberack_50ml_1',\n                           'location':'A1',\n                           'volume':1000,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            'wash buffer2':{'labware':'tuberack_50ml_1',\n                            'location':'A2',\n                            'volume':1000,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            'wash buffer3':{'labware':'tuberack_50ml_1',\n                            'location':'A3',\n                            'volume':1000,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            'wash buffer4':{'labware':'tuberack_50ml_1',\n                            'location':'B1',\n                            'volume':1000,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            'imaging buffer':{'labware':'tuberack_50ml_1',\n                                'location':'B2',\n                                'volume':750,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            'tcep':{'labware':'tuberack_50ml_1',\n                                'location':'B3',\n                                'volume':1000,\n                           'hardware;':'p1000',\n                           'repeat':2},\n            '2x-SSC':{'labware':'tuberack_50ml_1',\n                                'location':'A5',\n                                'volume':833,\n                           'hardware;':'p1000',\n                           'repeat':3},\n            'universal_fluors':{'labware':'tuberack_15ml_1',\n                                'location':'A1',\n                                'volume':750,\n                           'hardware;':'p1000',\n                           'repeat':2}}\n"

# %%
def generate_well_pos(well_num,total=96,ncol=12,nrow=8):
    row = well_num//ncol
    col = well_num%ncol
    return chr(65+row)+str(col+1)

# %%
num_rounds = 50
for i in range(num_rounds):
    reagents['round'+str(i+1)] = {'labware':'wellplate1',
                                'location':generate_well_pos(i),
                                'volume':750,
                           'hardware':'p1000',
                           'repeat':2}

# %%
def get_fluid_node(buffer):
    return fluids[fluids['BufferName']==buffer]['NodeID'].iloc[0]

# %%
experiment = {}

# %%
step_n = 0

# %%
reagents['round6']
# Out:
# {'labware': 'wellplate1',
#  'location': 'A6',
#  'volume': 750,
#  'hardware': 'p1000',
#  'repeat': 2}

# %%
for round_n in range(1,51):
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'liquid_handler'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['reagent'] = f'round{round_n}'
    experiment[step_n]['step_metadata']['info'] = reagents[f'round{round_n}']
    experiment[step_n]['step_metadata']['destination'] = 'syringe_adapter'
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('ot2')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 15*60 # 15 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('wash buffer')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('universal_fluors')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 15*60 # 15 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('wash buffer')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('imaging buffer')
    experiment[step_n]['step_metadata']['volume'] = 1.5
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 5*60 # 5 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'image'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['filename'] = f'round_{round_n}'
    experiment[step_n]['step_metadata']['callibrate_af'] = True
    experiment[step_n]['slack_notify'] = True
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('tcep')
    experiment[step_n]['step_metadata']['volume'] = 2
    experiment[step_n]['step_metadata']['speed'] = 0.5
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'wait'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['wait_time'] = 5*60 # 5 minutes
    experiment[step_n]['slack_notify'] = False
    step_n += 1
    
    experiment[step_n] = {}
    experiment[step_n]['step_type'] = 'fluid'
    experiment[step_n]['step_metadata'] = {}
    experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('2x-SSC')
    experiment[step_n]['step_metadata']['volume'] = 5
    experiment[step_n]['step_metadata']['speed'] = 1
    experiment[step_n]['slack_notify'] = False
    step_n += 1

# %%
experiment
# Out:
# {0: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round1',
#    'info': {'labware': 'wellplate1',
#     'location': 'A1',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  1: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  2: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  3: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  4: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  5: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  6: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  7: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  8: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  9: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_1', 'callibrate_af': True},
#   'slack_notify': True},
#  10: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  11: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  12: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  13: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round2',
#    'info': {'labware': 'wellplate1',
#     'location': 'A2',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  14: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  15: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  16: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  17: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  18: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  19: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  20: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  21: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  22: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_2', 'callibrate_af': True},
#   'slack_notify': True},
#  23: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  24: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  25: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  26: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round3',
#    'info': {'labware': 'wellplate1',
#     'location': 'A3',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  27: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  28: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  29: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  30: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  31: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  32: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  33: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  34: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  35: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_3', 'callibrate_af': True},
#   'slack_notify': True},
#  36: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  37: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  38: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  39: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round4',
#    'info': {'labware': 'wellplate1',
#     'location': 'A4',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  40: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  41: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  42: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  43: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  44: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  45: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  46: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  47: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  48: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_4', 'callibrate_af': True},
#   'slack_notify': True},
#  49: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  50: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  51: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  52: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round5',
#    'info': {'labware': 'wellplate1',
#     'location': 'A5',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  53: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  54: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  55: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  56: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  57: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  58: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  59: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  60: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  61: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_5', 'callibrate_af': True},
#   'slack_notify': True},
#  62: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  63: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  64: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  65: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round6',
#    'info': {'labware': 'wellplate1',
#     'location': 'A6',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  66: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  67: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  68: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  69: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  70: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  71: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  72: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  73: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  74: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_6', 'callibrate_af': True},
#   'slack_notify': True},
#  75: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  76: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  77: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  78: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round7',
#    'info': {'labware': 'wellplate1',
#     'location': 'A7',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  79: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  80: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  81: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  82: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  83: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  84: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  85: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  86: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  87: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_7', 'callibrate_af': True},
#   'slack_notify': True},
#  88: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  89: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  90: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  91: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round8',
#    'info': {'labware': 'wellplate1',
#     'location': 'A8',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  92: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  93: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  94: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  95: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  96: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  97: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  98: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  99: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  100: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_8', 'callibrate_af': True},
#   'slack_notify': True},
#  101: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  102: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  103: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  104: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round9',
#    'info': {'labware': 'wellplate1',
#     'location': 'A9',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  105: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  106: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  107: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  108: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  109: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  110: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  111: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  112: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  113: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_9', 'callibrate_af': True},
#   'slack_notify': True},
#  114: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  115: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  116: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  117: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round10',
#    'info': {'labware': 'wellplate1',
#     'location': 'A10',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  118: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  119: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  120: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  121: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  122: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  123: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  124: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  125: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  126: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_10', 'callibrate_af': True},
#   'slack_notify': True},
#  127: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  128: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  129: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  130: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round11',
#    'info': {'labware': 'wellplate1',
#     'location': 'A11',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  131: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  132: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  133: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  134: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  135: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  136: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  137: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  138: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  139: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_11', 'callibrate_af': True},
#   'slack_notify': True},
#  140: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  141: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  142: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  143: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round12',
#    'info': {'labware': 'wellplate1',
#     'location': 'A12',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  144: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  145: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  146: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  147: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  148: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  149: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  150: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  151: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  152: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_12', 'callibrate_af': True},
#   'slack_notify': True},
#  153: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  154: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  155: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  156: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round13',
#    'info': {'labware': 'wellplate1',
#     'location': 'B1',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  157: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  158: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  159: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  160: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  161: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  162: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  163: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  164: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  165: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_13', 'callibrate_af': True},
#   'slack_notify': True},
#  166: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  167: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  168: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  169: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round14',
#    'info': {'labware': 'wellplate1',
#     'location': 'B2',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  170: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  171: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  172: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  173: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  174: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  175: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  176: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  177: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  178: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_14', 'callibrate_af': True},
#   'slack_notify': True},
#  179: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  180: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  181: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  182: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round15',
#    'info': {'labware': 'wellplate1',
#     'location': 'B3',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  183: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  184: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  185: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  186: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  187: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  188: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  189: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  190: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  191: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_15', 'callibrate_af': True},
#   'slack_notify': True},
#  192: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  193: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  194: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  195: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round16',
#    'info': {'labware': 'wellplate1',
#     'location': 'B4',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  196: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  197: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  198: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  199: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  200: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  201: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  202: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  203: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  204: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_16', 'callibrate_af': True},
#   'slack_notify': True},
#  205: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  206: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  207: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  208: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round17',
#    'info': {'labware': 'wellplate1',
#     'location': 'B5',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  209: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  210: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  211: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  212: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  213: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  214: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  215: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  216: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  217: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_17', 'callibrate_af': True},
#   'slack_notify': True},
#  218: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  219: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  220: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  221: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round18',
#    'info': {'labware': 'wellplate1',
#     'location': 'B6',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  222: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  223: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  224: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  225: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  226: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  227: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  228: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  229: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  230: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_18', 'callibrate_af': True},
#   'slack_notify': True},
#  231: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  232: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  233: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  234: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round19',
#    'info': {'labware': 'wellplate1',
#     'location': 'B7',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  235: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  236: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  237: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  238: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  239: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  240: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  241: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  242: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  243: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_19', 'callibrate_af': True},
#   'slack_notify': True},
#  244: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  245: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  246: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  247: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round20',
#    'info': {'labware': 'wellplate1',
#     'location': 'B8',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  248: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  249: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  250: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  251: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  252: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  253: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  254: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  255: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  256: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_20', 'callibrate_af': True},
#   'slack_notify': True},
#  257: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  258: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  259: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  260: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round21',
#    'info': {'labware': 'wellplate1',
#     'location': 'B9',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  261: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  262: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  263: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  264: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  265: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  266: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  267: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  268: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  269: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_21', 'callibrate_af': True},
#   'slack_notify': True},
#  270: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  271: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  272: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  273: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round22',
#    'info': {'labware': 'wellplate1',
#     'location': 'B10',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  274: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  275: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  276: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  277: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  278: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  279: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  280: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  281: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  282: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_22', 'callibrate_af': True},
#   'slack_notify': True},
#  283: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  284: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  285: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  286: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round23',
#    'info': {'labware': 'wellplate1',
#     'location': 'B11',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  287: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  288: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  289: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  290: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  291: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  292: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  293: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  294: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  295: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_23', 'callibrate_af': True},
#   'slack_notify': True},
#  296: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  297: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  298: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  299: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round24',
#    'info': {'labware': 'wellplate1',
#     'location': 'B12',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  300: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  301: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  302: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  303: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  304: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  305: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  306: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  307: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  308: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_24', 'callibrate_af': True},
#   'slack_notify': True},
#  309: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  310: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  311: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  312: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round25',
#    'info': {'labware': 'wellplate1',
#     'location': 'C1',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  313: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  314: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  315: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  316: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  317: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  318: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  319: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  320: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  321: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_25', 'callibrate_af': True},
#   'slack_notify': True},
#  322: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  323: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  324: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  325: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round26',
#    'info': {'labware': 'wellplate1',
#     'location': 'C2',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  326: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  327: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  328: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  329: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  330: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  331: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  332: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  333: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  334: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_26', 'callibrate_af': True},
#   'slack_notify': True},
#  335: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  336: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  337: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  338: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round27',
#    'info': {'labware': 'wellplate1',
#     'location': 'C3',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  339: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  340: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  341: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  342: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  343: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  344: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  345: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  346: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  347: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_27', 'callibrate_af': True},
#   'slack_notify': True},
#  348: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  349: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  350: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  351: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round28',
#    'info': {'labware': 'wellplate1',
#     'location': 'C4',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  352: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  353: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  354: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  355: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  356: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  357: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  358: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  359: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  360: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_28', 'callibrate_af': True},
#   'slack_notify': True},
#  361: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  362: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  363: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  364: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round29',
#    'info': {'labware': 'wellplate1',
#     'location': 'C5',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  365: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  366: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  367: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  368: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  369: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  370: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  371: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  372: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  373: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_29', 'callibrate_af': True},
#   'slack_notify': True},
#  374: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  375: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  376: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  377: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round30',
#    'info': {'labware': 'wellplate1',
#     'location': 'C6',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  378: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  379: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  380: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  381: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  382: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  383: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  384: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  385: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  386: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_30', 'callibrate_af': True},
#   'slack_notify': True},
#  387: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  388: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  389: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  390: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round31',
#    'info': {'labware': 'wellplate1',
#     'location': 'C7',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  391: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  392: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  393: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  394: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  395: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
# ...
#  518: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  519: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  520: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round41',
#    'info': {'labware': 'wellplate1',
#     'location': 'D5',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  521: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  522: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  523: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  524: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  525: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  526: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  527: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  528: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  529: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_41', 'callibrate_af': True},
#   'slack_notify': True},
#  530: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  531: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  532: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  533: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round42',
#    'info': {'labware': 'wellplate1',
#     'location': 'D6',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  534: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  535: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  536: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  537: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  538: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  539: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  540: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  541: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  542: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_42', 'callibrate_af': True},
#   'slack_notify': True},
#  543: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  544: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  545: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  546: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round43',
#    'info': {'labware': 'wellplate1',
#     'location': 'D7',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  547: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  548: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  549: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  550: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  551: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  552: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  553: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  554: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  555: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_43', 'callibrate_af': True},
#   'slack_notify': True},
#  556: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  557: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  558: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  559: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round44',
#    'info': {'labware': 'wellplate1',
#     'location': 'D8',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  560: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  561: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  562: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  563: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  564: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  565: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  566: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  567: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  568: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_44', 'callibrate_af': True},
#   'slack_notify': True},
#  569: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  570: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  571: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  572: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round45',
#    'info': {'labware': 'wellplate1',
#     'location': 'D9',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  573: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  574: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  575: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  576: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  577: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  578: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  579: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  580: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  581: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_45', 'callibrate_af': True},
#   'slack_notify': True},
#  582: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  583: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  584: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  585: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round46',
#    'info': {'labware': 'wellplate1',
#     'location': 'D10',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  586: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  587: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  588: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  589: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  590: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  591: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  592: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  593: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  594: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_46', 'callibrate_af': True},
#   'slack_notify': True},
#  595: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  596: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  597: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  598: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round47',
#    'info': {'labware': 'wellplate1',
#     'location': 'D11',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  599: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  600: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  601: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  602: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  603: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  604: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  605: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  606: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  607: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_47', 'callibrate_af': True},
#   'slack_notify': True},
#  608: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  609: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  610: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  611: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round48',
#    'info': {'labware': 'wellplate1',
#     'location': 'D12',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  612: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  613: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  614: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  615: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  616: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  617: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  618: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  619: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  620: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_48', 'callibrate_af': True},
#   'slack_notify': True},
#  621: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  622: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  623: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  624: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round49',
#    'info': {'labware': 'wellplate1',
#     'location': 'E1',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  625: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  626: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  627: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  628: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  629: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  630: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  631: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  632: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  633: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_49', 'callibrate_af': True},
#   'slack_notify': True},
#  634: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  635: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  636: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False},
#  637: {'step_type': 'liquid_handler',
#   'step_metadata': {'reagent': 'round50',
#    'info': {'labware': 'wellplate1',
#     'location': 'E2',
#     'volume': 750,
#     'hardware': 'p1000',
#     'repeat': 2},
#    'destination': 'syringe_adapter'},
#   'slack_notify': False},
#  638: {'step_type': 'fluid',
#   'step_metadata': {'fluid': 'ot2', 'volume': 1.5, 'speed': 1},
#   'slack_notify': False},
#  639: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  640: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  641: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '6', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  642: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 900},
#   'slack_notify': False},
#  643: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '2', 'volume': 2, 'speed': 1},
#   'slack_notify': False},
#  644: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '3', 'volume': 1.5, 'speed': 0.5},
#   'slack_notify': False},
#  645: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  646: {'step_type': 'image',
#   'step_metadata': {'filename': 'round_50', 'callibrate_af': True},
#   'slack_notify': True},
#  647: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '4', 'volume': 2, 'speed': 0.5},
#   'slack_notify': False},
#  648: {'step_type': 'wait',
#   'step_metadata': {'wait_time': 300},
#   'slack_notify': False},
#  649: {'step_type': 'fluid',
#   'step_metadata': {'fluid': '5', 'volume': 5, 'speed': 1},
#   'slack_notify': False}}

# %%
experiment[646]
# Out:
# {'step_type': 'image',
#  'step_metadata': {'filename': 'round_50', 'callibrate_af': True},
#  'slack_notify': True}

# %%
del experiment[647]
del experiment[648]
del experiment[649]

# %%
step_n = 647

# %%
experiment[step_n] = {}
experiment[step_n]['step_type'] = 'fluid'
experiment[step_n]['step_metadata'] = {}
experiment[step_n]['step_metadata']['fluid'] = get_fluid_node('2x-SSC')
experiment[step_n]['step_metadata']['volume'] = 5
experiment[step_n]['step_metadata']['speed'] = 1
experiment[step_n]['slack_notify'] = False
step_n += 1

# %%
with open('experiment.json', 'w+') as f:
    json.dump(experiment, f, indent=4)

# %%
with open('ot2_config.json', 'w+') as f:
    json.dump(ot2_config, f, indent=4)

# %%
oni_params = {
    "cropping": {
        "top-left": [130, 5],
        "top-right": [140, 595],
        "width": 428,
        "height": 684
    },
    "safe_focus": {
        "upper_thresh": 2000,
        "lower_thresh": -450
    },
    "microscope_name": "60xAALZ7W2T",
    "xy_positions_mm": {},
    "z_relative_positions_um": [],
    "light_program":[{'laser_power': [10.0, 0.0, 0.0, 0.0], 'exposure_ms': 33}, # ordered 405, 488, 561, 640
                     {'laser_power': [0.0, 0.0, 10.0, 0.0], 'exposure_ms': 100},
                     {'laser_power': [0.0, 0.0, 0.0, 10.0], 'exposure_ms': 100}],
    "start_z": -675.533,
    "num_z_slices": 10,
    "relative_top_z_um": 2.0,
    "relative_bottom_z_um": -2.0,
    'fovIncrement_mm': {'x': 0.08345999908447266,'y': 0.13337998962402345} # ONI default with no overlap
}

def _make_tiles(starting_pos,n_x,n_y,x_inc_um,y_inc_um):
        x_start = starting_pos['x']
        y_start = starting_pos['y']
        positions = []
        xs = list(range(0,n_x))
        ys = list(range(0,n_y))
        if (len(ys) % 2) == 0:
            all_xs = (xs + list(reversed(xs)))*floor(len(ys)/2)
        else:
            all_xs = (xs + list(reversed(xs)))*floor(len(ys)/2)
            all_xs += xs
        all_ys = []
        for y in ys:
            all_ys += [y]*len(xs)
        tmp_positions = list(zip(all_xs,all_ys))
        positions = []
        for pos in tmp_positions:
            positions.append([x_start + (pos[0] * x_inc_um), y_start + (pos[1] * y_inc_um)])
        return positions

# custom_positions = None
def position_generator(oni_params,custom_positions,starting_xy_um={'x':0,'y':0},tile_num_x=1,tile_num_y=1,overlap=0.0):
    if custom_positions is not None:
        oni_params['xy_positions_mm'] = custom_positions
    else:
        x_inc_um = (oni_params['fovIncrement_mm']['x'] * 1000) * (1 - overlap)
        y_inc_um = (oni_params['fovIncrement_mm']['y'] * 1000) * (1 - overlap)
        oni_params['xy_positions_mm'] = _make_tiles(starting_xy_um,tile_num_x,tile_num_y,x_inc_um,y_inc_um)
    # generate relative_zs
    oni_params['z_relative_positions_um'] = np.linspace(oni_params['relative_top_z_um'],oni_params['relative_bottom_z_um'],oni_params['num_z_slices']).tolist()
    return oni_params

# %%
oni_params = position_generator(oni_params,None,{'x':5.25*1000,'y':2*1000},10,5,0.0)

# %%
with open('oni_params.pkl', 'wb') as f:
    pickle.dump(oni_params, f)

# %%
fluids
# Out:
#   NodeID    FluidType        BufferName  LoadVolume
# 0    ot2       source               ot2           3
# 1      2       source       wash buffer          40
# 2      3       source    imaging buffer          21
# 3      4       source              tcep          20
# 4      5       source            2x-SSC          50
# 5      6       source  universal_fluors          15
# 6  waste  destination        waste_tank           0

# %%
def get_fluid_name(nodeID):
    return fluids[fluids['NodeID']==nodeID]['BufferName'].iloc[0]

# %%
reagent_vols = {}
for i in experiment.keys():
    if experiment[i]['step_type'] == 'fluid':
        buffer = get_fluid_name(experiment[i]['step_metadata']['fluid'])
        if buffer not in reagent_vols:
            reagent_vols[buffer] = 0
        reagent_vols[buffer] += experiment[i]['step_metadata']['volume']

# %%
reagent_vols
# Out:
# {'ot2': 75.0,
#  'wash buffer': 200,
#  'universal_fluors': 75.0,
#  'imaging buffer': 75.0,
#  'tcep': 98,
#  '2x-SSC': 250}

# %%
for i in experiment.keys():
    if experiment[i]['step_type'] == 'liquid_handler':
        print(experiment[i]['step_metadata']['info']['location'])
# Out:
# A1
# A2
# A3
# A4
# A5
# A6
# A7
# A8
# A9
# A10
# A11
# A12
# B1
# B2
# B3
# B4
# B5
# B6
# B7
# B8
# B9
# B10
# B11
# B12
# C1
# C2
# C3
# C4
# C5
# C6
# C7
# C8
# C9
# C10
# C11
# C12
# D1
# D2
# D3
# D4
# D5
# D6
# D7
# D8
# D9
# D10
# D11
# D12
# E1
# E2
